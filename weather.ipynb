# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv('nyc_weather.csv')

# %%
weather.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
weather['Temperature'].max()
# Out:
# 50

# %%
weather['Temperature'].min()
# Out:
# 20

# %%
weather[['Temperature', 'DewPoint', 'CloudCover']]
# Out:
#     Temperature  DewPoint  CloudCover
# 0            38        23           5
# 1            36        18           3
# 2            40        21           1
# 3            25         9           3
# 4            20        -3           0
# 5            33         4           0
# 6            39        11           3
# 7            39        29           8
# 8            44        38           8
# 9            50        46           7
# 10           33         8           1
# 11           35        15           4
# 12           26         4           0
# 13           30        12           7
# 14           43        31           2
# 15           47        37           7
# 16           36        23           6
# 17           25         6           2
# 18           22         3           1
# 19           32        15           2
# 20           31        11           1
# 21           26         6           3
# 22           26        21           8
# 23           28        11           3
# ...

# %%
weather[['PrecipitationIn', 'Events', 'VisibilityMiles']]
# Out:
#    PrecipitationIn    Events  VisibilityMiles
# 0                0       NaN               10
# 1                0       NaN               10
# 2                0       NaN               10
# 3                0       NaN               10
# 4                0       NaN               10
# 5                0       NaN               10
# 6                0       NaN               10
# 7                0       NaN               10
# 8                T      Rain                9
# 9              1.8      Rain                4
# 10               0       NaN               10
# 11               T       NaN               10
# 12               0       NaN               10
# 13               T       NaN               10
# 14               T       NaN                9
# 15            0.24      Rain                8
# 16            0.05  Fog-Snow                8
# 17               T      Snow                9
# 18               0       NaN               10
# ...

# %%
weather[['PrecipitationIn', 'Events', 'VisibilityMiles']].head()
# Out:
#   PrecipitationIn Events  VisibilityMiles
# 0               0    NaN               10
# 1               0    NaN               10
# 2               0    NaN               10
# 3               0    NaN               10
# 4               0    NaN               10

# %%
weather[['PrecipitationIn', 'Events', 'VisibilityMiles']].tail()
# Out:
#    PrecipitationIn Events  VisibilityMiles
# 26               T   Rain               10
# 27               0    NaN               10
# 28               0    NaN               10
# 29               0    NaN               10
# 30               0    NaN               10

# %%
weather.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
weather.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
weather
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
weather.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
weather.set_index('DewPoint')
# Out:
#                 EST  Temperature  Humidity  Sea Level PressureIn  \
# DewPoint
#  23        1/1/2016           38        52                 30.03
#  18        1/2/2016           36        46                 30.02
#  21        1/3/2016           40        47                 29.86
#  9         1/4/2016           25        44                 30.05
# -3         1/5/2016           20        41                 30.57
#  4         1/6/2016           33        35                 30.50
#  11        1/7/2016           39        33                 30.28
#  29        1/8/2016           39        64                 30.20
#  38        1/9/2016           44        77                 30.16
#  46       1/10/2016           50        71                 29.59
#  8        1/11/2016           33        37                 29.92
#  15       1/12/2016           35        53                 29.85
#  4        1/13/2016           26        42                 29.94
# ...
